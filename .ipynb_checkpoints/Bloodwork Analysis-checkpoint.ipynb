# %%
pip install langchain-google-genai
# Out:
# Requirement already satisfied: langchain-google-genai in C:\Code\Ai Agent\.venv\Lib\site-packages (4.2.7)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in C:\Code\Ai Agent\.venv\Lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<3.0.0,>=1.65.0 in C:\Code\Ai Agent\.venv\Lib\site-packages (from langchain-google-genai) (2.11.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.7 in C:\Code\Ai Agent\.venv\Lib\site-packages (from langchain-google-genai) (1.4.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in C:\Code\Ai Agent\.venv\Lib\site-packages (from langchain-google-genai) (2.13.4)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in C:\Code\Ai Agent\.venv\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.14.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in C:\Code\Ai Agent\.venv\Lib\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.55.2)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in C:\Code\Ai Agent\.venv\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in C:\Code\Ai Agent\.venv\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.34.2)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in C:\Code\Ai Agent\.venv\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in C:\Code\Ai Agent\.venv\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (16.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in C:\Code\Ai Agent\.venv\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Code\Ai Agent\.venv\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in C:\Code\Ai Agent\.venv\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in C:\Code\Ai Agent\.venv\Lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.18)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Code\Ai Agent\.venv\Lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in C:\Code\Ai Agent\.venv\Lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (49.0.0)
# Requirement already satisfied: certifi in C:\Code\Ai Agent\.venv\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in C:\Code\Ai Agent\.venv\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Code\Ai Agent\.venv\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Code\Ai Agent\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-google-genai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Code\Ai Agent\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-google-genai) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Code\Ai Agent\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-google-genai) (0.10.1)
# Requirement already satisfied: packaging>=23.2.0 in C:\Code\Ai Agent\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-google-genai) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Code\Ai Agent\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-google-genai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Code\Ai Agent\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-google-genai) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Code\Ai Agent\.venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.7->langchain-google-genai) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in C:\Code\Ai Agent\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-google-genai) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Code\Ai Agent\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-google-genai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Code\Ai Agent\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-google-genai) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Code\Ai Agent\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-google-genai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Code\Ai Agent\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Code\Ai Agent\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Code\Ai Agent\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Code\Ai Agent\.venv\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Code\Ai Agent\.venv\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.7.0)
# Requirement already satisfied: cffi>=2.0.0 in C:\Code\Ai Agent\.venv\Lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.1.0)
# Requirement already satisfied: pycparser in C:\Code\Ai Agent\.venv\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in C:\Code\Ai Agent\.venv\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.6.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

# Pointing directly to the subfolder where your keys are actually saved
load_dotenv("C:/Code/Ai Agent/1_simple_llm_calling/.env")

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
with open("Bloodwork.txt", "r") as f:
    blood_report = f.read()

print(blood_report[:200])
# Out:
# Patient: Rajesh Sharma, Age 48, Male
# Date: May 7, 2026
#
# COMPLETE BLOOD COUNT (CBC)
# --------------------------
# Hemoglobin:        15.1 g/dL        (Normal: 13.5â€“17.5)
# Hematocrit:        44%

# %%
extraction_prompt = f"""
You are a medical data extraction assistant.

from the report below, extract All test values and classify each on as HIGH, LOW, or NORMAL
based on the reference ranges provided in the report.

Format your response as:
- Test Name: value | Status: HIGH/LOW/NORMAL | Reference: range

Blood Report:
{blood_report}
"""

extraction_response = llm.invoke(extraction_prompt)
extracted_values = extraction_response.text

print("=== STAGE 1: EXTRACTED VALUES ===")
print(extracted_values)
# Out:
# === STAGE 1: EXTRACTED VALUES ===
# Here are the extracted test values and their classifications:
#
# - Hemoglobin: 15.1 g/dL | Status: NORMAL | Reference: 13.5–17.5
# - Hematocrit: 44% | Status: NORMAL | Reference: 41–53%
# - WBC: 6.8 x10^3/uL | Status: NORMAL | Reference: 4.5–11.0
# - Platelets: 220 x10^3/uL | Status: NORMAL | Reference: 150–400
# - Total Cholesterol: 238 mg/dL | Status: HIGH | Reference: <200
# - LDL Cholesterol: 162 mg/dL | Status: HIGH | Reference: <100
# - HDL Cholesterol: 36 mg/dL | Status: LOW | Reference: >40
# - Triglycerides: 188 mg/dL | Status: HIGH | Reference: <150
# - Glucose (Fasting): 92 mg/dL | Status: NORMAL | Reference: 70–99
# - HbA1c: 5.3% | Status: NORMAL | Reference: <5.7%
# - Creatinine: 1.0 mg/dL | Status: NORMAL | Reference: 0.7–1.3
# - eGFR: 82 mL/min | Status: NORMAL | Reference: >60
# - ALT: 28 U/L | Status: NORMAL | Reference: 7–40
# - AST: 25 U/L | Status: NORMAL | Reference: 10–40
# - Bilirubin Total: 0.8 mg/dL | Status: NORMAL | Reference: 0.2–1.2

# %%
diet_prompt = f"""
You are a clinical nutritionist specialing in Indian dietary habit

Based on the blood work analysis below, write:
1. A short health summary in 4-5 lines explaining the patient's condition in simple language
2. A short, practical Indian diet paln having only two sections (1) Foods to avoid (2) Foods to eat more of.
  Do not include any other sections in diet plan.

Blood Work Analysis:
{extracted_values}
"""

diet_response = llm.invoke(diet_prompt)

print("=== STAGE 2: HEALTH SUMMARY & DIET PLAN ===")
print(diet_response.text)
# Out:
# === STAGE 2: HEALTH SUMMARY & DIET PLAN ===
# Hello there! I've reviewed your blood work results. Here's a summary and a dietary plan tailored for you:
#
# ---
#
# **1. Health Summary:**
#
# Your overall blood counts, blood sugar levels, and organ functions (kidney and liver) are currently within healthy limits, which is great news. However, your cholesterol and triglyceride levels are elevated, with your "bad" cholesterol (LDL) being high and "good" cholesterol (HDL) being low. This pattern indicates an increased risk for heart health issues and suggests a need for focused dietary and lifestyle adjustments to improve your lipid profile.
#
# ---
#
# **2. Practical Indian Diet Plan:**
#
# **Foods to Avoid:**
#
# *   **Deep-fried foods:** Limit or avoid items like samosas, pakoras, puri, bhature, vada, and commercially fried snacks.
# *   **Foods high in refined flour (maida):** Reduce consumption of white bread, naan, biscuits, pastries, and instant noodles.
# *   **Full-fat dairy and red meat:** Cut down on full-cream milk, excess ghee, mawa-based sweets, and red meat like mutton or buffalo.
# *   **Sugary drinks and processed sweets:** Avoid sodas, packaged fruit juices, mithai (Indian sweets) with excess sugar, and highly processed foods.
#
# **Foods to Eat More Of:**
#
# *   **Whole Grains:** Include whole wheat roti, oats, brown rice, ragi, bajra, jowar, and barley in your daily meals.
# *   **Legumes & Pulses:** Incorporate all varieties of dal (moong, masoor, arhar, chana), rajma, chole, and sprouts for protein and fiber.
# *   **Fruits & Vegetables:** Eat a wide array of fresh seasonal fruits and plenty of green leafy vegetables (like spinach, fenugreek, mustard greens) and other colorful vegetables daily.
# *   **Healthy Fats:** Consume nuts (almonds, walnuts), seeds (flaxseeds, chia seeds), and use mustard oil, rice bran oil, or olive oil in moderation for cooking.
# *   **Lean Protein:** Opt for skinless chicken, fish (especially fatty fish like sardines, mackerel), and low-fat dairy options (skim milk, curd/dahi).
# *   **Fiber-rich additions:** Consider adding psyllium husk (isabgol) or fenugreek seeds to your diet regularly to aid in cholesterol management.
